# %%
import pandas as pd

# %%
import tabula
pdf_path="https://www.sec.gov/files/investment/13flist2023q3.pdf"
dfs=tabula.read_pdf(input_path=pdf_path,pages=3)

# %%
pd.DataFrame(dfs[0])
# Out:
#     B38564 10 8    *                    EURONAV NV               SHS  \
# 0   B38564 90 8  NaN                    EURONAV NV              CALL
# 1   B38564 95 8  NaN                    EURONAV NV               PUT
# 2   B6S7WD 10 6  NaN                    NYXOAH S A               SHS
# 3   C00948 10 6    *  AGRIFORCE GROWING SYSTEMS LT               COM
# 4   C00948 90 6  NaN  AGRIFORCE GROWING SYSTEMS LT              CALL
# 5   C00948 95 6  NaN  AGRIFORCE GROWING SYSTEMS LT               PUT
# 6   C00948 11 4  NaN  AGRIFORCE GROWING SYSTEMS LT  *W EXP 02/01/202
# 7   C96657 11 6  NaN  VISION MARINE TECHNOLOGIES I               COM
# 8   D18190 89 8    *             DEUTSCHE BANK A G         NAMEN AKT
# 9   D18190 90 8  NaN             DEUTSCHE BANK A G              CALL
# 10  D18190 95 8  NaN             DEUTSCHE BANK A G               PUT
# 11  F21107 10 1    *                CONSTELLIUM SE          CL A SHS
# 12  F21107 90 1  NaN                CONSTELLIUM SE              CALL
# ...

# %%
dfs[0]
# Out:
#     B38564 10 8    *                    EURONAV NV               SHS  \
# 0   B38564 90 8  NaN                    EURONAV NV              CALL
# 1   B38564 95 8  NaN                    EURONAV NV               PUT
# 2   B6S7WD 10 6  NaN                    NYXOAH S A               SHS
# 3   C00948 10 6    *  AGRIFORCE GROWING SYSTEMS LT               COM
# 4   C00948 90 6  NaN  AGRIFORCE GROWING SYSTEMS LT              CALL
# 5   C00948 95 6  NaN  AGRIFORCE GROWING SYSTEMS LT               PUT
# 6   C00948 11 4  NaN  AGRIFORCE GROWING SYSTEMS LT  *W EXP 02/01/202
# 7   C96657 11 6  NaN  VISION MARINE TECHNOLOGIES I               COM
# 8   D18190 89 8    *             DEUTSCHE BANK A G         NAMEN AKT
# 9   D18190 90 8  NaN             DEUTSCHE BANK A G              CALL
# 10  D18190 95 8  NaN             DEUTSCHE BANK A G               PUT
# 11  F21107 10 1    *                CONSTELLIUM SE          CL A SHS
# 12  F21107 90 1  NaN                CONSTELLIUM SE              CALL
# ...

# %%
from tabulate import tabulate
tabulate(dfs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 from tabulate import tabulate
# ----> 2 tabulate(dfs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tabulate\__init__.py:2048, in tabulate(tabular_data, headers, tablefmt, floatfmt, intfmt, numalign, stralign, missingval, showindex, disable_numparse, colalign, maxcolwidths, rowalign, maxheadercolwidths)
#    2045 if tabular_data is None:
#    2046     tabular_data = []
# -> 2048 list_of_lists, headers = _normalize_tabular_data(
#    2049     tabular_data, headers, showindex=showindex
#    2050 )
#    2051 list_of_lists, separating_lines = _remove_separating_lines(list_of_lists)
#    2053 if maxcolwidths is not None:
#
# ...
