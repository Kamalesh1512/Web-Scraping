# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# %%
header={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage=requests.get('https://www.heac.gov.om/index.php/en/institutions',headers=header).text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
header=[]
for i in soup.find('table',class_='inner-content-table').find_all('th'):
    header.append(i.text.strip())
    
header
# Out:
# ['LOCATION',
#  'INSTITUTION',
#  'CODE',
#  'WEB SITE',
#  'PHONE',
#  'FAX',
#  'AL-KHOUDH',
#  'Sultan Qaboos University',
#  'SQ',
#  'www.squ.edu.om',
#  '24413333',
#  '24413861',
#  'Associated with Central Bank of Oman',
#  'Associated with Ministry of Awqaf and Religious Affairs',
#  'ALKHUWAYR',
#  'Institute of Sharia Sciences',
#  'IS',
#  'www.css.edu.om',
#  '24393711',
#  '24393801',
#  'Associated with Ministry of Higher Education',
#  'SOHAR',
#  'Former College of Education ( SOHAR )',
#  'SH',
#  'www.cas.edu.om',
#  '22056900',
#  '22057001',
#  'IBRI',
#  'Former College of Education ( IBRI )',
#  'SB',
#  'www.cas.edu.om',
#  '25690159',
#  '25691696',
#  'SALALAH',
#  'Former College of Education ( SALALAH )',
#  'SL',
#  'www.cas.edu.om',
#  '23226611',
#  '23225620',
#  'Airport Heights',
#  'Internal Scholarships Department',
#  'SF SP SA SR',
#  'www.mohe.gov.om',
#  '24340838\n24340817\n24340825',
#  '24340815',
#  'Associated with Ministry of Manpower',
# ...

# %%
# Out:
#                                                 0
# 0                                        LOCATION
# 1                                     INSTITUTION
# 2                                            CODE
# 3                                        WEB SITE
# 4                                           PHONE
# ..                                            ...
# 187  Global College of Engineering and Technology
# 188                                            GE
# 189                               www.gcet.edu.om
# 190                            24227900\n24227903
# 191                                      24227901
#
# [192 rows x 1 columns]

# %%
import urllib.request
import pandas as pd
url = "https://www.heac.gov.om/index.php/en/institutions"

with urllib.request.urlopen(url) as i:
    html = i.read()
    
data = pd.read_html(html)[0]
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[57], line 5
#       2 import pandas as pd
#       3 url = "https://www.heac.gov.om/index.php/en/institutions"
# ----> 5 with urllib.request.urlopen(url) as i:
#       6     html = i.read()
#       8 data = pd.read_html(html)[0]
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# ...
